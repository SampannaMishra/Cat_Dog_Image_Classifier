# %%
import numpy as np

# %%
import cv2

# %%
import os
import random
import matplotlib.pyplot as plt
import pickle
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
DIRECTORY = r'C:\Users\SAMPANNA MISHRA\OneDrive\Desktop\archive\dataset\dogscats'
CATEGORIES = ['cats','dogs']

# %%
IMG_SIZE = 100

data = []

for category in CATEGORIES:
    folder = os.path.join(DIRECTORY,category)
    label = CATEGORIES.index(category)
    for img in os.listdir(folder):
        img_path = os.path.join(folder,img)
        img_arr = cv2.imread(img_path)
        img_arr = cv2.resize(img_arr, (IMG_SIZE,IMG_SIZE))
        data.append([img_arr, label])

# %%
len(data)
# Out:
# 23000

# %%
random.shuffle(data)

# %%
data[0]
# Out:
# [array([[[ 90, 150, 176],
#          [ 96, 155, 181],
#          [ 94, 155, 181],
#          ...,
#          [ 44,  99, 120],
#          [ 37,  88, 108],
#          [ 32,  80,  98]],
#
#         [[ 32, 109, 148],
#          [ 50, 126, 162],
#          [ 56, 133, 160],
#          ...,
#          [ 39, 109, 131],
#          [ 38, 107, 126],
#          [ 37, 107, 124]],
#
#         [[ 24, 111, 147],
#          [ 30, 111, 148],
#          [ 34, 111, 147],
#          ...,
#          [ 37,  96, 124],
#          [ 36, 100, 124],
#          [ 35, 102, 123]],
#
#         ...,
#
#         [[ 75, 147, 165],
#          [ 81, 150, 169],
#          [ 83, 150, 168],
#          ...,
#          [ 52,  98, 126],
#          [ 54, 101, 129],
#          [ 60, 114, 141]],
#
#         [[ 86, 154, 173],
#          [ 88, 154, 173],
#          [ 90, 152, 172],
#          ...,
#          [ 49,  95, 124],
#          [ 67, 107, 136],
#          [ 67, 113, 141]],
#
#         [[ 76, 137, 157],
#          [ 69, 142, 164],
#          [ 67, 140, 161],
#          ...,
#          [ 79, 110, 140],
#          [ 63, 116, 143],
#          [ 71, 117, 146]]], dtype=uint8),
#  1]

# %%
X =[]
y= []

for features,labels in data:
    X.append(features)
    y.append(labels)

# %%
X = np.array(X)
y = np.array(y)

# %%
len(y)
# Out:
# 23000

# %%
pickle.dump(X, open('X.pkl','wb'))
pickle.dump(y, open('y.pkl','wb'))
